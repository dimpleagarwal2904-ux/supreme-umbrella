# %%
#learn how to ask for input
name = input("What is your name? ")
print("Hello," , name)
# Out:
# Hello, Dimple

# %%
#remember input always returns a string. you have to type the data type you want to convert it to. 
#for example- int(input()) returns integer value
#input is blocking. program doesnt work until user enters text.

# %%
#interesting thing- getpass. the user's typed 
# characters will not appear on screen
#used like the following

from getpass import getpass
password= getpass("Password: ")
print("Password length: ", len(password))
# Out:
# Password length:  11
