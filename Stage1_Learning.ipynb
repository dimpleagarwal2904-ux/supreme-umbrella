# %%
x=10
if x==1:
    print("Dimple rocks")
else:
    print("Dimple remembers Krishna")
# colon is used. Also indentation is used instead of curly brackets. no paranthesis after if commands
# Out:
# Dimple remembers Krishna

# %%
n= 9.9
print(n)
# Out:
# 9.9

# %%
15/7
# Out:
# 2.142857142857143

# %%
15//7
# Out:
# 2

# %%
5*2
# Out:
# 10

# %%
5**2
# when we use double ** it takes power function to the number of *. for cube, use ***
# Out:
# 25

# %%
n='doesn\'t'
print(n)
# Out:
# doesn't

# %%
n= "doesn't"
print(n)
# Out:
# doesn't

# %%
#use \ depending on double quotes or single quotes usage and what you want to print

# %%
s="First line.\nSecond line"
print(s)
# Out:
# First line.
# Second line

# %%
s= "First line.\n Second line"
print(s)
# Out:
# First line.
#  Second line

# %%
s=r"First line.\nSecond line"
print(s)
# the use of character r in the front negates the \n command
# Out:
# First line.\nSecond line

# %%
3*"un" + "mium"
# Out:
# 'unununmium'

# %%
"Py""thon"
# Out:
# 'Python'

# %%
'Py''thon'
# Out:
# 'Python'

# %%
"un"*3 +"ium"
# Out:
# 'unununium'

# %%
("un"*3)"ium"
# Out:
#   Cell In[45], line 1
#     ("un"*3)"ium"
#             ^
# SyntaxError: invalid syntax

# %%
"un"*3""ium"
# Out:
#   Cell In[46], line 1
#     "un"*3""ium"
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
word= 'python'

word[0]
# Out:
# 'p'

# %%
word[5]
# Out:
# 'n'

# %%
#keep in mind that the counting starts from 0. so the 6th position is actually labelled 5

# %%
word[0:2]
# Out:
# 'py'

# %%
word[:4]
# the indice shows the number of positions. so only till 0,1,2,3 characters are printed.
# Out:
# 'pyth'

# %%
word[4:]
# Out:
# 'on'

# %%
word[-4:]
# Out:
# 'thon'

# %%
word[:2]+word[2:]
# Out:
# 'python'

# %%
word[-6:]
# Out:
# 'python'

# %%
'Jy' + word[2:]
# Out:
# 'Jython'

# %%
s= "DimpleislookingforKrishna"
len(s)
# Out:
# 25

# %%
a=5
b=6
print(a<b)
# Out:
# True

# %%
print( (a>b) or (a<100))
# Out:
# True

# %%
print((a>b) and (a<100))
# Out:
# False

# %%
print(not(a<b))
# Out:
# False

# %%
print(!(a<b))
# Out:
#   Cell In[70], line 1
#     print(!(a<b))
#           ^
# SyntaxError: invalid syntax

# %%
#This prints out "Dimple is 21 years old"
name= "Dimple"
age= 21
print(" %s is %d years old" %(name, age))
# Out:
#  Dimple is 21 years old

# %%
name="Paridhi"
age= 13
print(" %s is %d years old" %(name, age))
# Out:
#  Paridhi is 13 years old

# %%
mylist= [1,2,4]
print(" A list %s" % mylist)
# Out:
#  A list [1, 2, 4]

# %%
#%s - String (or any object with a string representation, like numbers)

#%d - Integers

#%f - Floating point numbers

#%.<number of digits>f - Floating point numbers with a fixed amount of digits to the right of the dot.

#%x/%X - Integers in hex representation (lowercase/uppercase)

# %%
newlist=[]
newlist.append(1)
newlist.append(3)
newlist.append(5)
print(newlist)
# Out:
# [1, 3, 5]

# %%
print(newlist[2])
# Out:
# 5

# %%
numbers=[]
strings=[]
numbers.append(1)
numbers.append(2)
numbers.append(3)
strings.append("hello")
strings.append("world")
second_name= strings[1]

print(numbers)
print(strings)
print("the second name on the names list is %s" % second_name)
# Out:
# [1, 2, 3]
# ['hello', 'world']
# the second name on the names list is world

# %%
# !cd ~/Desktop/python-quant\ learn/

# %%
# !git --version
# Out:
# xcode-select: note: No developer tools were found, requesting install.
# If developer tools are located at a non-default location on disk, use `sudo xcode-select --switch path/to/Xcode.app` to specify the Xcode that you wish to use for command line developer tools, and cancel the installation dialog.
# See `man xcode-select` for more details.

# %%
# !git --version
# Out:
# git version 2.39.5 (Apple Git-154)
